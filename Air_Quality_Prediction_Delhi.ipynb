# %% [markdown]
# # Air Quality Prediction using Machine Learning
#
# In this machine learning project, we use multiple publically available datasets to better predict the air quality in the capital city of Delhi, India. We look at the correlation between weather conditions and the Air Quality Index.
#
# The data is imported from a .csv file that has both air quality and weather data for the city from 2015 to April 2020. The data is synoptic(3-hourly).
#
# * The Air Quality Data is obtained from a Kaggle dataset that uses publicly available data provided by the [Central Pollution Control Board](https://cpcb.nic.in/).
#
# * The Weather Data is obtained from the [Reliable Prognosis Weather Archive](https://rp5.ru/Weather_archive_in_New_Delhi,_Safdarjung_(airport)), for the Safdarjung weather station in Delhi.
#
# In total, the dataset contains over 15,000 rows.

# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

#Seaborn beautifiers for plotting
sns.set(
        rc={
 'axes.axisbelow': False,
 'axes.edgecolor': 'lightgrey',
 'axes.facecolor': 'None',
 'axes.grid': False,
 'axes.labelcolor': 'dimgrey',
 'axes.spines.right': False,
 'axes.spines.top': False,
 'figure.facecolor': 'white',
 'lines.solid_capstyle': 'round',
 'patch.edgecolor': 'w',
 'patch.force_edgecolor': True,
 'text.color': 'dimgrey',
 'xtick.bottom': False,
 'xtick.color': 'dimgrey',
 'xtick.direction': 'out',
 'xtick.top': False,
 'ytick.color': 'dimgrey',
 'ytick.direction': 'out',
 'ytick.left': False,
 'ytick.right': False})

sns.set_context('notebook', rc={"font.size":16,
                                "axes.titlesize":20,
                                "axes.labelsize":18})
plt.rcParams["figure.figsize"] = [16,9]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/MCA mp1/final_dataset.csv')

# %%
df.head()
# Out:
#                   Date  PM2.5    PM10     NO    NO2    NOx    NH3    CO  \
# 0  2020-04-30 23:00:00  59.68  122.26  13.00  29.68  29.70  33.57  1.00
# 1  2020-04-30 20:00:00  50.73  190.73  18.08  19.29  28.60  33.13  0.78
# 2  2020-04-30 17:00:00  42.53  108.07  19.01  15.48  10.95  34.14  0.81
# 3  2020-04-30 14:00:00  47.40  109.09  14.91  14.41  23.49  31.32  0.83
# 4  2020-04-30 11:00:00  63.73  132.04   9.85  15.65  18.34  33.20  0.84
#
#      SO2     O3    AQI AQI_Category  Month  Day  Hour  Temp  Rel_Humidity  \
# 0  14.41  29.85  145.0     Moderate      4   30    23  28.0          70.0
# 1  15.46  69.34  149.0     Moderate      4   30    20  30.2          65.0
# 2  21.66  94.92  145.0     Moderate      4   30    17  36.6          46.0
# 3  20.95  91.61  136.0     Moderate      4   30    14  37.8          40.0
# 4  20.07  69.94  117.0     Moderate      4   30    11  34.6          50.0
#
#                      Wind_Direction  Wind_Speed
# 0  Wind blowing from the north-east         2.0
# 1        Wind blowing from the east         1.0
# 2  Wind blowing from the north-east         3.0
# 3  Wind blowing from the north-west         3.0
# 4  Wind blowing from the south-east         3.0

# %%
df.dtypes
# Out:
# Date               object
# PM2.5             float64
# PM10              float64
# NO                float64
# NO2               float64
# NOx               float64
# NH3               float64
# CO                float64
# SO2               float64
# O3                float64
# AQI               float64
# AQI_Category       object
# Month               int64
# Day                 int64
# Hour                int64
# Temp              float64
# Rel_Humidity      float64
# Wind_Direction     object
# Wind_Speed        float64
# dtype: object

# %% [markdown]
# # Exploratory Data Analysis
#
# Let us see what features affect the PM 2.5 levels through visualizations.

# %%
x = df['Month']
y = df['PM2.5']
plt.scatter(x,y)
plt.xlabel('Month')
plt.ylabel('PM 2.5 Level')
plt.title('PM 2.5 Levels by Month')
plt.show()

# %%
x = df['Wind_Speed']
y = df['PM2.5']
plt.scatter(x,y)
plt.xlabel('Wind Speed (Metres Per Second)')
plt.ylabel('PM 2.5 Level')
plt.title('PM 2.5 Levels with Wind Speed')
plt.show()

# %%
x = df['Rel_Humidity']
y = df['PM2.5']
plt.scatter(x,y)
plt.xlabel('Relative Humidity')
plt.ylabel('PM 2.5 Level')
plt.title('PM 2.5 by Relative Humidity')
plt.show()

# %%
x = df['Hour']
y = df['PM2.5']
plt.scatter(x,y)
plt.xlabel('Hour')
plt.ylabel('PM2.5 Level')
plt.title('PM2.5 by Hour')
plt.show()

# %%
import datetime as dt
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Day_of_The_Week'] = df['Date'].dt.day_name()

# %%
load = df[['PM2.5', 'Day_of_The_Week']].groupby(['Day_of_The_Week']).mean()

# %%
load.plot(kind='bar')
# Out:
# <Axes: xlabel='Day_of_The_Week'>

# %% [markdown]
# ## Initial Observations
#
# * From the graphs we can observe that in the winter months of October, November and December the PM 2.5 levels reach their highest levels. This makes Month a good predictor.
#
# * However, Hour and Day of the Week are not that good as PM 2.5 predictors.
#
# * With higher wind speeds the PM 2.5 levels decrease. Can't tell for Relative Humidity.

# %% [markdown]
# # Cleaning the Data
#
# Let us first minimize the number of attributes. Since we are only considering PM 2.5 levels at the moment, we can get rid of all other pollutants.

# %%
df.columns
# Out:
# Index(['Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3',
#        'AQI', 'AQI_Category', 'Month', 'Day', 'Hour', 'Temp', 'Rel_Humidity',
#        'Wind_Direction', 'Wind_Speed', 'Day_of_The_Week'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Date', 'PM25', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3',
#        'AQI', 'AQI_Category', 'Month', 'Day', 'Hour', 'Temp', 'Rel_Humidity',
#        'Wind_Direction', 'Wind_Speed'],
#       dtype='object')

# %%
df2 = df.drop(labels=['PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3','AQI','AQI_Category','Day','Wind_Direction','Day_of_The_Week'], axis=1)

# %%
df2.rename(columns={"PM2.5": "PM25"}, inplace=True)

# %%
df2.head()
# Out:
#                  Date   PM25  Month  Hour  Temp  Rel_Humidity  Wind_Speed
# 0 2020-04-30 23:00:00  59.68      4    23  28.0          70.0         2.0
# 1 2020-04-30 20:00:00  50.73      4    20  30.2          65.0         1.0
# 2 2020-04-30 17:00:00  42.53      4    17  36.6          46.0         3.0
# 3 2020-04-30 14:00:00  47.40      4    14  37.8          40.0         3.0
# 4 2020-04-30 11:00:00  63.73      4    11  34.6          50.0         3.0

# %% [markdown]
# ## Creating Previous Value Features
# Using weather conditions of the previous 5 instances leading to the current instance will give our model more features to work with and will better improve accuracy.

# %%
# Creating Previous Value Features
df2['Value_1'] = df2.PM25.shift(periods=1)
df2['TEMP_1'] = df2.Temp.shift(periods=1)
df2['SPD_1'] = df2.Wind_Speed.shift(periods=1)
df2['HUM_1'] = df2.Rel_Humidity.shift(periods=1)

df2['Value_2'] = df2.PM25.shift(periods=2)
df2['TEMP_2'] = df2.Temp.shift(periods=2)
df2['SPD_2'] = df2.Wind_Speed.shift(periods=2)
df2['HUM_2'] = df2.Rel_Humidity.shift(periods=2)

df2['Value_3'] = df2.PM25.shift(periods=3)
df2['TEMP_3'] = df2.Temp.shift(periods=3)
df2['SPD_3'] = df2.Wind_Speed.shift(periods=3)
df2['HUM_3'] = df2.Rel_Humidity.shift(periods=3)

df2['Value_4'] = df2.PM25.shift(periods=4)
df2['TEMP_4'] = df2.Temp.shift(periods=4)
df2['SPD_4'] = df2.Wind_Speed.shift(periods=4)
df2['HUM_4'] = df2.Rel_Humidity.shift(periods=4)

df2['Value_5'] = df2.PM25.shift(periods=5)
df2['TEMP_5'] = df2.Temp.shift(periods=5)
df2['SPD_5'] = df2.Wind_Speed.shift(periods=5)
df2['HUM_5'] = df2.Rel_Humidity.shift(periods=5)

# %%
df2.head(10)
# Out:
#                  Date   PM25  Month  Hour  Temp  Rel_Humidity  Wind_Speed  \
# 0 2020-04-30 23:00:00  59.68      4    23  28.0          70.0         2.0
# 1 2020-04-30 20:00:00  50.73      4    20  30.2          65.0         1.0
# 2 2020-04-30 17:00:00  42.53      4    17  36.6          46.0         3.0
# 3 2020-04-30 14:00:00  47.40      4    14  37.8          40.0         3.0
# 4 2020-04-30 11:00:00  63.73      4    11  34.6          50.0         3.0
# 5 2020-04-30 08:00:00  50.71      4     8  28.2          76.0         2.0
# 6 2020-04-30 05:00:00  43.42      4     5  26.4          80.0         2.0
# 7 2020-04-30 02:00:00  47.57      4     2  27.0          77.0         3.0
# 8 2020-04-29 23:00:00  60.57      4    23  28.4          70.0         2.0
# 9 2020-04-29 20:00:00  58.18      4    20  30.2          61.0         1.0
#
#    Value_1  TEMP_1  SPD_1  ...  SPD_3  HUM_3  Value_4  TEMP_4  SPD_4  HUM_4  \
# 0      NaN     NaN    NaN  ...    NaN    NaN      NaN     NaN    NaN    NaN
# 1    59.68    28.0    2.0  ...    NaN    NaN      NaN     NaN    NaN    NaN
# 2    50.73    30.2    1.0  ...    NaN    NaN      NaN     NaN    NaN    NaN
# 3    42.53    36.6    3.0  ...    2.0   70.0      NaN     NaN    NaN    NaN
# 4    47.40    37.8    3.0  ...    1.0   65.0    59.68    28.0    2.0   70.0
# 5    63.73    34.6    3.0  ...    3.0   46.0    50.73    30.2    1.0   65.0
# 6    50.71    28.2    2.0  ...    3.0   40.0    42.53    36.6    3.0   46.0
# 7    43.42    26.4    2.0  ...    3.0   50.0    47.40    37.8    3.0   40.0
# 8    47.57    27.0    3.0  ...    2.0   76.0    63.73    34.6    3.0   50.0
# 9    60.57    28.4    2.0  ...    2.0   80.0    50.71    28.2    2.0   76.0
#
#    Value_5  TEMP_5  SPD_5  HUM_5
# 0      NaN     NaN    NaN    NaN
# 1      NaN     NaN    NaN    NaN
# 2      NaN     NaN    NaN    NaN
# 3      NaN     NaN    NaN    NaN
# 4      NaN     NaN    NaN    NaN
# 5    59.68    28.0    2.0   70.0
# 6    50.73    30.2    1.0   65.0
# 7    42.53    36.6    3.0   46.0
# 8    47.40    37.8    3.0   40.0
# 9    63.73    34.6    3.0   50.0
#
# [10 rows x 27 columns]

# %%
#Remove outliers (PM 2.5 values should be in the range 1-500)
df2 = df2[df2.PM25<=500]
df2.shape
# Out:
# (15129, 27)

# %%
#Only taking data till before the 2020 pandemic caused a nationwide lockdown
df2 = df2[df2.Date<='2020-03-24']
df2.shape
# Out:
# (14826, 27)

# %% [markdown]
# ## Handling NaNs

# %%
# Are there null values in our dataset?
df2.isnull().values.any()
# Out:
# True

# %%
# 1. Check if Date, Month, or Hour have NaNs
print("Date contains NaNs:", df2.Date.isnull().values.any())
print("Month contains NaNs:", df2.Month.isnull().values.any())
print("Hour contains NaNs:", df2.Hour.isnull().values.any())
# Out:
# Date contains NaNs: False
# Month contains NaNs: False
# Hour contains NaNs: False

# %%
# 2. Drop any row where PM 2.5 level is missing

# Show rows where value is NaN
df2[df2['PM25'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Date, PM25, Month, Hour, Temp, Rel_Humidity, Wind_Speed, Value_1, TEMP_1, SPD_1, HUM_1, Value_2, TEMP_2, SPD_2, HUM_2, Value_3, TEMP_3, SPD_3, HUM_3, Value_4, TEMP_4, SPD_4, HUM_4, Value_5, TEMP_5, SPD_5, HUM_5]
# Index: []
#
# [0 rows x 27 columns]

# %%
df2 = df2.dropna(axis=0,subset=['PM25'])
df2.shape
# Out:
# (14826, 27)

# %%
print("Temperature contains NaNs:", df2.Temp.isnull().values.any())
# Out:
# Temperature contains NaNs: True

# %%
df2[df2['Temp'].isnull()].shape
# Out:
# (40, 27)

# %%
# Show rows where DEWP & TEMP is NaN
df2[df2['Rel_Humidity'].isnull() & df2['Temp'].isnull()].head(20)
# Out:
#                     Date    PM25  Month  Hour  Temp  Rel_Humidity  Wind_Speed  \
# 1015 2019-12-23 14:00:00  187.46     12    14   NaN           NaN        21.0
# 1141 2019-12-07 11:00:00  307.88     12    11   NaN           NaN         7.0
# 1195 2019-11-30 17:00:00   72.57     11    17   NaN           NaN         0.0
# 1802 2019-09-14 08:00:00   24.75      9     8   NaN           NaN         NaN
# 2981 2019-04-16 17:00:00   39.91      4    17   NaN           NaN         NaN
# 3871 2018-12-25 08:00:00  252.67     12     8   NaN           NaN         0.0
# 4220 2018-11-10 05:00:00  292.67     11     5   NaN           NaN        14.0
# 4221 2018-11-09 23:00:00  290.85     11    23   NaN           NaN         NaN
# 4590 2018-09-24 02:00:00   14.13      9     2   NaN           NaN         NaN
# 4666 2018-09-14 11:00:00   30.79      9    11   NaN           NaN         4.0
# 5162 2018-07-13 14:00:00   45.31      7    14   NaN           NaN         1.0
# 6499 2018-01-24 20:00:00  110.92      1    20   NaN           NaN        12.0
# 6652 2018-01-05 08:00:00  162.20      1     8   NaN           NaN         0.0
# 6747 2017-12-24 05:00:00  219.19     12     5   NaN           NaN         0.0
# 6756 2017-12-23 02:00:00  130.90     12     2   NaN           NaN         4.0
# 6817 2017-12-15 08:00:00  112.44     12     8   NaN           NaN         0.0
# 7021 2017-11-19 02:00:00  123.40     11     2   NaN           NaN         NaN
# 7049 2017-11-15 11:00:00  186.31     11    11   NaN           NaN         NaN
# 7570 2017-09-10 17:00:00   45.24      9    17   NaN           NaN         NaN
# 8074 2017-07-08 14:00:00   64.00      7    14   NaN           NaN         3.0
#
#       Value_1  TEMP_1  SPD_1  ...  SPD_3  HUM_3  Value_4  TEMP_4  SPD_4  \
# 1015   200.04    12.4    1.0  ...    0.0  100.0   210.65     9.4    2.0
# 1141   177.18    24.2    1.0  ...    0.0   96.0   301.08    12.8    0.0
# 1195    92.53    14.6    1.0  ...    1.0  100.0   122.81    10.8    1.0
# 1802    34.65    33.0    2.0  ...    2.0   63.0    25.44    30.8    1.0
# 2981    30.07    23.0    4.0  ...    4.0   62.0    12.19    20.8    1.0
# 3871   270.87    16.2    2.0  ...    2.0   75.0   270.89    11.0    1.0
# 4220   313.70    25.0    1.0  ...    2.0   40.0   219.32    24.0    0.0
# 4221   292.67     NaN   14.0  ...    1.0   49.0   214.52    28.2    2.0
# 4590    14.66    24.4    3.0  ...    2.0   92.0    25.70    26.8    1.0
# 4666    31.61    34.4    4.0  ...    0.0   75.0    47.34    28.2    0.0
# 5162    24.76    26.2    3.0  ...    0.0   98.0    37.21    28.2    0.0
# 6499   163.64    10.8    0.0  ...    3.0  100.0    70.02    10.4    4.0
# 6652   248.01    12.6    3.0  ...    0.0   75.0   285.18    10.8    1.0
# 6747   211.40     8.0    0.0  ...    0.0   40.0   138.09    21.0    0.0
# 6756   120.33    12.4    2.0  ...    3.0   46.0    82.50    24.0    5.0
# 6817   178.99    15.6    2.0  ...    1.0   64.0    98.37    12.6    2.0
# 7021   101.47    15.4    2.0  ...    4.0   46.0   118.20    24.0    2.0
# 7049   145.28    27.4    1.0  ...    0.0   81.0   232.50    16.4    0.0
# 7570    35.02    32.4    0.0  ...    0.0   86.0    59.28    28.0    0.0
# 8074    60.00    36.4    2.0  ...    0.0   79.0    91.50    31.0    0.0
#
#       HUM_4  Value_5  TEMP_5  SPD_5  HUM_5
# 1015   95.0   215.88     9.2    2.0   92.0
# 1141   96.0   303.72    11.4    0.0   97.0
# 1195   97.0   130.77    12.6    1.0   91.0
# 1802   76.0    26.45    30.0    2.0   80.0
# 2981   82.0    31.72    23.6    5.0   66.0
# 3871   97.0   332.64     9.0    1.0  100.0
# 4220   66.0   303.14    17.4    0.0   90.0
# 4221   40.0   219.32    24.0    0.0   66.0
# 4590   89.0    24.62    25.2    4.0   91.0
# 4666   85.0    56.44    27.4    2.0   76.0
# 5162   94.0    40.95    27.4    0.0   97.0
# 6499  100.0    88.01    13.4    4.0   88.0
# 6652   88.0   298.53     8.6    0.0   92.0
# 6747   55.0   203.59    12.0    0.0   88.0
# 6756   36.0    55.46    21.0    2.0   52.0
# 6817   79.0   112.64    10.6    3.0   92.0
# 7021   36.0    94.55    21.0    0.0   52.0
# 7049   90.0   220.82    15.8    0.0   94.0
# 7570   87.0    76.48    29.6    0.0   80.0
# 8074   83.0    78.00    30.0    0.0   86.0
#
# [20 rows x 27 columns]

# %%
# Since these are only 20 records, we can drop them
df2 = df2.dropna(axis=0,subset=['Temp', 'Rel_Humidity'])
df2.shape
# Out:
# (14767, 27)

# %%
print("Wind speed contains nulls:", df2.Wind_Speed.isnull().values.any())
# Out:
# Wind speed contains nulls: True

# %%
df2[df2['Wind_Speed'].isnull()].head(20)
# Out:
#                      Date    PM25  Month  Hour  Temp  Rel_Humidity  \
# 968   2019-12-30 08:00:00  216.22     12     8   5.4         100.0
# 3863  2018-12-26 08:00:00  229.61     12     8   7.0          97.0
# 4860  2018-08-20 23:00:00   41.62      8    23  29.2          83.0
# 5751  2018-04-29 14:00:00   89.29      4    14  39.6          27.0
# 10396 2016-09-18 08:00:00   90.93      9     8  29.0          78.0
# 11310 2016-05-26 11:00:00  112.78      5    11  37.0          44.0
# 13519 2015-08-19 23:00:00   47.28      8    23  30.4          73.0
#
#        Wind_Speed  Value_1  TEMP_1  SPD_1  ...  SPD_3  HUM_3  Value_4  TEMP_4  \
# 968           NaN   245.50     7.8    1.0  ...    1.0   97.0   357.43     7.4
# 3863          NaN   254.42    17.2    2.0  ...    1.0   58.0   300.94     8.6
# 4860          NaN    30.53    28.6    2.0  ...    2.0   83.0    33.50    33.8
# 5751          NaN    77.98    38.0    0.0  ...    0.0   84.0    76.42    26.2
# 10396         NaN    54.90    34.8    3.0  ...    3.0   52.0    78.25    31.0
# 11310         NaN   115.81    38.4    4.0  ...    0.0   49.0   176.25    32.8
# 13519         NaN    17.00    29.4    4.0  ...    4.0   72.0    32.96    32.4
#
#        SPD_4  HUM_4  Value_5  TEMP_5  SPD_5  HUM_5
# 968      2.0  100.0   267.62     6.6    2.0   97.0
# 3863     0.0  100.0   408.46     7.2    0.0   97.0
# 4860     2.0   66.0    31.52    36.4    2.0   58.0
# 5751     0.0   84.0    66.63    25.6    0.0   76.0
# 10396    0.0   66.0   103.67    28.4    0.0   78.0
# 11310    0.0   58.0   160.59    31.6    0.0   64.0
# 13519    8.0   64.0    36.92    34.0    5.0   55.0
#
# [7 rows x 27 columns]

# %%
# Since these are only 8 records, we can drop them
df2 = df2.dropna(axis=0,subset=['Wind_Speed'])
df2.shape
# Out:
# (14760, 27)

# %%
df2['SPD_1'] = df2.SPD_1.fillna(value=0)
df2['SPD_2'] = df2.SPD_2.fillna(value=0)
df2['SPD_3'] = df2.SPD_3.fillna(value=0)
df2['SPD_4'] = df2.SPD_3.fillna(value=0)
df2['SPD_5'] = df2.SPD_3.fillna(value=0)

# %%
df2['HUM_1'] = df2.HUM_1.ffill()
df2['HUM_2'] = df2.HUM_2.ffill()
df2['HUM_3'] = df2.HUM_3.ffill()
df2['HUM_4'] = df2.HUM_4.ffill()
df2['HUM_5'] = df2.HUM_5.ffill()

# %%
df2['TEMP_1'] = df2.TEMP_1.ffill()
df2['TEMP_2'] = df2.TEMP_2.ffill()
df2['TEMP_3'] = df2.TEMP_3.ffill()
df2['TEMP_4'] = df2.TEMP_4.ffill()
df2['TEMP_5'] = df2.TEMP_5.ffill()

# %%
df2['Value_1'] = df2.Value_1.ffill()
df2['Value_2'] = df2.Value_2.ffill()
df2['Value_3'] = df2.Value_3.ffill()
df2['Value_4'] = df2.Value_4.ffill()
df2['Value_5'] = df2.Value_5.ffill()

# %%
# Are there null values in our dataset?
df2.isnull().values.any()
# Out:
# False

# %%
df2 = df2.reset_index(drop=True)

# %%
df2.shape
# Out:
# (14760, 27)

# %%
df2.dtypes
# Out:
# Date            datetime64[ns]
# PM25                   float64
# Month                    int64
# Hour                     int64
# Temp                   float64
# Rel_Humidity           float64
# Wind_Speed             float64
# Value_1                float64
# TEMP_1                 float64
# SPD_1                  float64
# HUM_1                  float64
# Value_2                float64
# TEMP_2                 float64
# SPD_2                  float64
# HUM_2                  float64
# Value_3                float64
# TEMP_3                 float64
# SPD_3                  float64
# HUM_3                  float64
# Value_4                float64
# TEMP_4                 float64
# SPD_4                  float64
# HUM_4                  float64
# Value_5                float64
# TEMP_5                 float64
# SPD_5                  float64
# HUM_5                  float64
# dtype: object

# %% [markdown]
# # Visualization with Cleaned Data

# %%
g = sns.PairGrid(df2, vars=["Month", "Hour", "PM25", "Wind_Speed", "Temp"], dropna=True)
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter);

# %%
g = sns.FacetGrid(df2, col='Month', col_wrap=4)
g.map(plt.scatter, "Temp","PM25")
plt.show()

# %%
g = sns.FacetGrid(df2, col='Month', col_wrap=4)
g.map(plt.scatter,"Wind_Speed", "PM25")
plt.show()

# %%
corr = df2.corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
# Out:
# <Axes: >

# %%
# Assuming 'df' is your DataFrame
# Select only numerical features for correlation calculation
numerical_features = df.select_dtypes(include=np.number).columns

# Calculate the correlation matrix for numerical features only
corr = df[numerical_features].corr()

# Generate the heatmap
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
plt.show()

# %%
data = df2.drop(['Date'], axis=1)
data.columns
# Out:
# Index(['PM25', 'Month', 'Hour', 'Temp', 'Rel_Humidity', 'Wind_Speed',
#        'Value_1', 'TEMP_1', 'SPD_1', 'HUM_1', 'Value_2', 'TEMP_2', 'SPD_2',
#        'HUM_2', 'Value_3', 'TEMP_3', 'SPD_3', 'HUM_3', 'Value_4', 'TEMP_4',
#        'SPD_4', 'HUM_4', 'Value_5', 'TEMP_5', 'SPD_5', 'HUM_5'],
#       dtype='object')

# %%
cols = data.columns.tolist()

# %%
#Export cleaned dataset
data.to_csv('final_datset_cleaned.csv')

# %% [markdown]
# # Applying Machine Learning Algorithms
#
# First, we need to split our data into training and testing data. Then, we build different models and compare their performance to see which works best. I will be looking at RMS Error and choose the model with the lowest value. We shall compare simple regression with a decision tree approach to see which works better.

# %%
y = data['PM25']
X = data.drop(['PM25'], axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=1234)

# %%
X_train.shape, y_train.shape
# Out:
# ((10332, 25), (10332,))

# %%
X_test.shape, y_test.shape
# Out:
# ((4428, 25), (4428,))

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Create linear regression object
regr = LinearRegression()

# %%
# Train the model using the training sets
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions using the testing set
lin_pred = regr.predict(X_test)

# %%
linear_regression_score = regr.score(X_test, y_test)
linear_regression_score
# Out:
# 0.7619333513056376

# %%
from math import sqrt
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Root mean squared error: %.2f"
      % sqrt(mean_squared_error(y_test, lin_pred)))
# The absolute squared error
print("Mean absolute error: %.2f"
      % mean_absolute_error(y_test, lin_pred))
# Explained variance score: 1 is perfect prediction
print('R-squared: %.2f' % r2_score(y_test, lin_pred))
# Out:
# Coefficients:
#  [ 7.12960389e-01 -3.89845855e-01 -2.75440751e+00  1.21664690e-02
#   4.01048488e-01  7.22383828e-01  3.16232373e+00  7.92620704e-02
#  -3.26267569e-01 -7.35746631e-02 -1.23505522e+00 -6.75753215e-01
#   1.15452650e-01  3.66309925e-02 -3.41698804e+00 -5.13187950e-03
#  -3.56324568e-01  3.06623098e-02  6.32369640e+00 -5.13187950e-03
#   2.25511145e-01  1.06451887e-01 -3.49415606e+00 -5.13187950e-03
#  -5.06823002e-02]
# Root mean squared error: 41.96
# Mean absolute error: 27.46
# R-squared: 0.76

# %%
plt.scatter(y_test, lin_pred)
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.title('Linear Regression Predicted vs Actual')
plt.show()

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


# Create Random Forrest Regressor object
regr_rf = RandomForestRegressor(n_estimators=200, random_state=1234)

# %%
regr_rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=1234)

# %%
# Score the model
decision_forest_score = regr_rf.score(X_test, y_test)
decision_forest_score
# Out:
# 0.8346107836722558

# %%
# Make predictions using the testing set
regr_rf_pred = regr_rf.predict(X_test)

# %%
# The mean squared error
print("Root mean squared error: %.2f"
      % sqrt(mean_squared_error(y_test, regr_rf_pred)))
# The absolute squared error
print("Mean absolute error: %.2f"
      % mean_absolute_error(y_test, regr_rf_pred))
# Explained variance score: 1 is perfect prediction
print('R-squared: %.2f' % r2_score(y_test, regr_rf_pred))
# Out:
# Root mean squared error: 34.98
# Mean absolute error: 22.70
# R-squared: 0.83

# %%
plt.scatter(y_test, regr_rf_pred)
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.title('Decision Forest Predicted vs Actual')
plt.show()

# %% [markdown]
# The Random Forest regressor outperformed linear regression, and it gives a better fit with lower RMS error.

# %%
import pickle

# %%
filename='AQP.sav'
pickle.dump(regr_rf, open(filename, 'wb'))
#loaded_model = pickle.load(open('AQP.sav', 'rb'))
#

# %%
for a in X.columns:
  print(a)
# Out:
# Month
# Hour
# Temp
# Rel_Humidity
# Wind_Speed
# Value_1
# TEMP_1
# SPD_1
# HUM_1
# Value_2
# TEMP_2
# SPD_2
# HUM_2
# Value_3
# TEMP_3
# SPD_3
# HUM_3
# Value_4
# TEMP_4
# SPD_4
# HUM_4
# Value_5
# TEMP_5
# SPD_5
# HUM_5
